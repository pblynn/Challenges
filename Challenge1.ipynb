# %% [markdown]
# ## Make a copy of this notebook and upload the completed notebook (in .ipynb format) to your GitHub.

# %%
# Write a program that will work out the distance travelled if the user enters 
# the speed and the time.
s= int(input("Enter the speed: "))
t= int(input("Enter the time: "))
distance= s*t
print (distance)
# Out:
# Enter the speed: 3
# Enter the time: 2
# 6

# %%
# Write a program to tell you the speed you would have to travel at in order 
# to go a distance within a certain time entered.
d= int(input("Enter the distance to go, in m: "))
t= int(input("Enter the time needed, in seconds: "))
s= d/t 
print("Speed required is",s, "m/s")
# Out:
# Enter the distance to go, in m: 100
# Enter the time needed, in seconds: 13
# Speed required is 7.6923076923076925 m/s

# %%
# Write a program to work out how many days you have lived for.
import datetime 
from datetime import date
today= date.today()

birthday= datetime.date(int(input("Year:")), int(input("Month:")),int(input("Day:")))
 
print ((today-birthday).days)
# Out:
# Year:1991
# Month:07
# Day:20
# 9424

# %%
# Write a program to work out how many seconds you have lived for.
import datetime 
from datetime import date
today= date.today()

birthday= datetime.date(int(input("Year:")), int(input("Month:")),int(input("Day:")))
days=(today-birthday).days
    
print (days*24*60*60)
# Out:
# Year:2000
# Month:08
# Day:10
# 528336000

# %%
# Write a program that will accept a date of birth and determine whether one 
# is considered an adult (i.e. 21 years old).
import datetime 
from datetime import date 
today= date.today() 

birthday= datetime.date(int(input("Year:")), int(input("Month:")), int(input("Day:")))
days=(today-birthday).days
if days>=7665:
    print("You are considered an adult.")
else:
    print("You are not considered an adult.")
# Out:
# Year:2000
# Month:08
# Day:10
# You are not considered an adult.

# %%
# Write a program that will generate a random playing card e.g. '9 Hearts',
# 'Queen Spades' when the return key is pressed.
# Note: Rather than generate a random number from 1 to 52. Create two random 
# numbers â one for the suit and one for the card.

    
from random import randint
card={11:"Jack",12:"Queen",13:"King"}
suit={1:"Spades",2:"Hearts",3:"Clubs",4:"Diamonds"}
card1=randint(11,13)
suit1=randint(1,4)

if i<=10:
    print (i) 
else:
    print (card[card1], end=" ")
print(suit[suit1])
# Out:
# King Spades

# %%
# Make a game of rock, paper, scissors against the computer.
# Algorithm
# Tell user to enter either rock,paper or scissors
# Get the response
# Generate a random number from 1 to 3 (1=rock,2=paper,3=scissors)
# Compare user selection and computer selection
# Display who wins.
from random import randint 

userChoice= input("rock, paper or scissors?: ")
choice={"rock":1,"paper":2,"scissors":3}
r=randint(1,3)


if userChoice in choice:
    if (choice[userChoice])==r:
        print("It's a Draw!")
    elif (choice[userChoice])<r or (choice[userChoice])=='3' and r=='1' :
        print("Computer Wins!")
    else:
        print ("User Wins!")
# Out:
# rock, paper or scissors?: rock
# It's a Draw!

# %%
# For the rock, paper, scissors game above, ensure that the user enters a valid 
# entry. Add a loop structure to play several times and keep a running score.

from random import randint 

result=0

for result in range(10):
    userChoice= input("rock, paper or scissors?: ")
    choice={"rock":1,"paper":2,"scissors":3}
    r=randint(1,3)
    
    if userChoice in choice:
        if (choice[userChoice])==r:
            print("It's a Draw!")
            
        elif (choice[userChoice])<r or (choice[userChoice])=='3' and r=='1' :
            print("Computer Wins!")
            
        else:
            print ("User Wins!")
            result+=1
        
        print("Score is ",result)
# Out:
# rock, paper or scissors?: rock
# Computer Wins!
# Score is  0
# rock, paper or scissors?: paper
# User Wins!
# Score is  2
# rock, paper or scissors?: scissors
# It's a Draw!
# Score is  2

# %%
# Write a program that will give the answer to logic gate questions e.g.
# Enter logic gate : OR
# Enter first input : 1
# Enter second input :0
# Result = 1
# It should work for the logic gates OR, XOR, NAND and NOR gates.

logic= input("Enter logic gate: ")
a= input("Enter first input: ")
b= input("Enter second input: ")

if logic=="OR":
    if a=='1' and b=='1':
        result= 1
    else:
        result= 0
    print (result) 

if logic=="XOR":
    if a=='1' or b=='1':
        result= 1 
    else:
        result=0 
    print (result) 

if logic=="NAND":
    if a=='1' and b=='1':
        result=0
    else:
        result=1
    print (result) 
        
if logic=="NOR":
    if a=='0' and b=='0':
        result=1
    else:
        result=0
    print (result)
# Out:
# Enter logic gate: OR
# Enter first input: 1
# Enter second input: 1
# 1

# %%
# Write a program that will display all the factors of an input number that
# are bigger than 1.
# (e.g. the factors of the number 12 are 6,4,3 and 2 because they divide
# into 12 exactly).
# Hint: To find out whether a number X is a factor of Y use:
# If Y mod X == 0 (there is nothing remaining when Y is divided by X)

num=int(input("Enter number: "))
for i in range(2,num):
    if (num%i==0):
        print(i, end=" ")
# Out:
# Enter number: 299
# 13 23
